# %% [markdown]
# ### Forecasting - Jordan

# %%
import pandas as pd 
import numpy as np 

import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, Flatten
from keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras import regularizers
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('data/conflict-clusters.csv')

# %%
# Locating events within Jordan
data = df.loc[df['country'] == 'Jordan', :]

# %%
data.shape
# Out:
# (376, 58)

# %%
# Dropping unecessary modeling columns
data.drop(columns=['year', 
                   'sub_event_type',
                   'actor1',
                   'assoc_actor_1',
                   'inter1',
                   'actor2',
                   'assoc_actor_2',
                   'inter2',
                   'interaction',
                   'region',
                   'admin2',
                   'admin3',
                   'location',
                   'timestamp',
                   'country',
                   'MA/CU'], inplace=True)

# %%
# Calculating weekly event count
df = (pd.to_datetime(data['event_date']).dt.floor('d').value_counts().rename_axis('date').reset_index(name='count'))

# %%
df.head()
# Out:
#         date  count
# 0 2018-05-31      9
# 1 2019-06-11      7
# 2 2017-12-07      6
# 3 2019-09-09      6
# 4 2019-04-16      6

# %%
data['event_date'] = pd.to_datetime(data['event_date'])

# %%
# Merging jordan events and weekly event counts
data = pd.merge(data, df, left_on='event_date', right_on='date', how='outer')

# %%
data.set_index('event_date', inplace=True)

# %%
data.drop(columns='date', inplace=True)

# %%
# Creating dummy variables from admin1 location
pd.get_dummies(data=data, 
               columns=['event_type',
                        'admin1'])
# Out:
#             latitude  longitude  geo_precision  fatalities  users  frac  \
# event_date
# 2017-01-06   30.1962    35.7341              3           1     66    61
# 2017-01-15   31.9552    35.9450              1           0     77    66
# 2017-01-21   33.3141    38.7034              1          11     72    65
# 2017-02-11   31.1637    35.7620              1           0    267    65
# 2017-02-14   31.9552    35.9450              1           0    342    53
# ...              ...        ...            ...         ...    ...   ...
# 2019-12-06   31.9552    35.9450              1           0     43    64
# 2019-12-08   31.9552    35.9450              1           0     50    59
# 2019-12-21   31.9552    35.9450              1           0     50    54
# 2019-12-24   32.5556    35.8500              2           0     46    54
# 2019-12-28   31.9552    35.9450              1           0     45    54
#
#             month  missing_data  Exchange rate USD  Unemployment rate  ...  \
# event_date                                                             ...
# 2017-01-06      1           0.0             0.7089              15.11  ...
# 2017-01-15      1           0.0             0.7089              15.11  ...
# 2017-01-21      1           0.0             0.7089              15.11  ...
# 2017-02-11      2           0.0             0.7089              15.11  ...
# 2017-02-14      2           0.0             0.7089              15.11  ...
# ...           ...           ...                ...                ...  ...
# 2019-12-06     12           0.0             0.7092              14.72  ...
# 2019-12-08     12           0.0             0.7092              14.72  ...
# 2019-12-21     12           0.0             0.7092              14.72  ...
# 2019-12-24     12           0.0             0.7092              14.72  ...
# 2019-12-28     12           0.0             0.7092              14.72  ...
#
#             admin1_Al Balqa  admin1_Al Karak  admin1_Al Mafraq  admin1_Amman  \
# event_date
# 2017-01-06                0                0                 0             0
# 2017-01-15                0                0                 0             1
# 2017-01-21                0                0                 1             0
# 2017-02-11                0                1                 0             0
# 2017-02-14                0                0                 0             1
# ...                     ...              ...               ...           ...
# 2019-12-06                0                0                 0             1
# 2019-12-08                0                0                 0             1
# 2019-12-21                0                0                 0             1
# 2019-12-24                0                0                 0             0
# 2019-12-28                0                0                 0             1
#
#             admin1_At Tafilah  admin1_Az Zarqa  admin1_Irbid  admin1_Jerash  \
# event_date
# 2017-01-06                  0                0             0              0
# 2017-01-15                  0                0             0              0
# 2017-01-21                  0                0             0              0
# 2017-02-11                  0                0             0              0
# 2017-02-14                  0                0             0              0
# ...                       ...              ...           ...            ...
# 2019-12-06                  0                0             0              0
# 2019-12-08                  0                0             0              0
# 2019-12-21                  0                0             0              0
# 2019-12-24                  0                0             1              0
# 2019-12-28                  0                0             0              0
#
#             admin1_Maan  admin1_Madaba
# event_date
# 2017-01-06            1              0
# 2017-01-15            0              0
# 2017-01-21            0              0
# 2017-02-11            0              0
# 2017-02-14            0              0
# ...                 ...            ...
# 2019-12-06            0              0
# 2019-12-08            0              0
# 2019-12-21            0              0
# 2019-12-24            0              0
# 2019-12-28            0              0
#
# [376 rows x 57 columns]

# %%
data.drop(columns=['event_type', 'admin1'], inplace=True)

# %%
y = data['count']
X = data.drop(columns=['count'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False)

# %%
minmax = MinMaxScaler()

# %%
# Normalizing numerical data
X_train = minmax.fit_transform(X_train)
X_test = minmax.fit_transform(X_test)

# %%
X_train.shape
# Out:
# (282, 39)

# %%
train = TimeseriesGenerator(X_train, y_train, length=3, batch_size=64)
test = TimeseriesGenerator(X_test, y_test, length=3, batch_size=64)

# %%
batch_x, batch_y = train[0]

# %%
batch_x.shape
# Out:
# (64, 3, 39)

# %%
# The LSTM design
model = Sequential()
# First LSTM layer with Dropout 
model.add(LSTM(32, activation='relu', kernel_regularizer=regularizers.l1(1e-5),return_sequences=True, input_shape=(3, 39)))
model.add(Dropout(0.7))
# Second LSTM layer
model.add(LSTM(units=32, activation='relu', kernel_regularizer=regularizers.l1(1e-5),return_sequences=True))
model.add(Dropout(0.7))
# Third LSTM layer
model.add(LSTM(units=32, activation='relu', return_sequences=True))
model.add(Dropout(0.7))
# The output layer

model.add(Flatten())
model.add(Dense(1))

# Compiling the RNN
model.compile(optimizer='Adam', loss='mean_absolute_percentage_error')
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_28 (LSTM)               (None, 3, 32)             9216
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 3, 32)             0
# _________________________________________________________________
# lstm_29 (LSTM)               (None, 3, 32)             8320
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 3, 32)             0
# _________________________________________________________________
# lstm_30 (LSTM)               (None, 3, 32)             8320
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 3, 32)             0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 96)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 97
# =================================================================
# Total params: 25,953
# Trainable params: 25,953
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting to the training set
hist = model.fit_generator(train, validation_data=(test), epochs=100)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 2s 400ms/step - loss: 99.7005 - val_loss: 98.9561
# Epoch 2/100
# 5/5 [==============================] - 0s 12ms/step - loss: 98.7840 - val_loss: 97.8377
# Epoch 3/100
# 5/5 [==============================] - 0s 19ms/step - loss: 97.5202 - val_loss: 96.4918
# Epoch 4/100
# 5/5 [==============================] - 0s 21ms/step - loss: 95.9749 - val_loss: 94.8290
# Epoch 5/100
# 5/5 [==============================] - 0s 21ms/step - loss: 93.2431 - val_loss: 92.6699
# Epoch 6/100
# 5/5 [==============================] - 0s 20ms/step - loss: 90.4077 - val_loss: 89.7413
# Epoch 7/100
# 5/5 [==============================] - 0s 20ms/step - loss: 84.4754 - val_loss: 85.5876
# Epoch 8/100
# 5/5 [==============================] - 0s 20ms/step - loss: 73.9274 - val_loss: 79.7150
# Epoch 9/100
# 5/5 [==============================] - 0s 21ms/step - loss: 66.3339 - val_loss: 73.0989
# Epoch 10/100
# 5/5 [==============================] - 0s 19ms/step - loss: 67.6324 - val_loss: 68.0018
# Epoch 11/100
# 5/5 [==============================] - 0s 20ms/step - loss: 66.0805 - val_loss: 68.1485
# Epoch 12/100
# 5/5 [==============================] - 0s 11ms/step - loss: 46.6761 - val_loss: 24.3951
# Epoch 76/100
# 5/5 [==============================] - 0s 12ms/step - loss: 45.5639 - val_loss: 24.4249
# Epoch 77/100
# 5/5 [==============================] - 0s 11ms/step - loss: 45.5946 - val_loss: 24.1485
# Epoch 78/100
# 5/5 [==============================] - 0s 11ms/step - loss: 45.0157 - val_loss: 25.1653
# Epoch 79/100
# 5/5 [==============================] - 0s 11ms/step - loss: 47.0617 - val_loss: 25.1701
# Epoch 80/100
# 5/5 [==============================] - 0s 11ms/step - loss: 46.0321 - val_loss: 24.3313
# Epoch 81/100
# 5/5 [==============================] - 0s 10ms/step - loss: 45.0659 - val_loss: 24.0075
# Epoch 82/100
# 5/5 [==============================] - 0s 10ms/step - loss: 47.1572 - val_loss: 24.2030
# Epoch 83/100
# 5/5 [==============================] - 0s 9ms/step - loss: 46.0199 - val_loss: 24.2179
# Epoch 84/100
# 5/5 [==============================] - 0s 8ms/step - loss: 44.0593 - val_loss: 23.6352
# Epoch 85/100
# 5/5 [==============================] - 0s 9ms/step - loss: 45.1333 - val_loss: 24.3232
# Epoch 86/100
# 5/5 [==============================] - 0s 9ms/step - loss: 45.9768 - val_loss: 24.3571
# Epoch 87/100
# 5/5 [==============================] - 0s 9ms/step - loss: 46.2977 - val_loss: 24.2984
# Epoch 88/100
# 5/5 [==============================] - 0s 9ms/step - loss: 45.1221 - val_loss: 24.1813
# Epoch 89/100
# 5/5 [==============================] - 0s 8ms/step - loss: 45.3234 - val_loss: 24.2754
# Epoch 90/100
# 5/5 [==============================] - 0s 8ms/step - loss: 46.0601 - val_loss: 23.9411
# Epoch 91/100
# 5/5 [==============================] - 0s 9ms/step - loss: 45.1903 - val_loss: 23.9676
# Epoch 92/100
# 5/5 [==============================] - 0s 8ms/step - loss: 45.1635 - val_loss: 24.7295
# Epoch 93/100
# 5/5 [==============================] - 0s 8ms/step - loss: 45.3995 - val_loss: 24.3045
# Epoch 94/100
# 5/5 [==============================] - 0s 9ms/step - loss: 44.4307 - val_loss: 23.8710
# Epoch 95/100
# 5/5 [==============================] - 0s 10ms/step - loss: 45.3682 - val_loss: 23.6209
# Epoch 96/100
# 5/5 [==============================] - 0s 10ms/step - loss: 44.6047 - val_loss: 23.8834
# Epoch 97/100
# 5/5 [==============================] - 0s 9ms/step - loss: 44.2193 - val_loss: 24.2233
# Epoch 98/100
# 5/5 [==============================] - 0s 9ms/step - loss: 46.6430 - val_loss: 24.1304
# Epoch 99/100
# 5/5 [==============================] - 0s 11ms/step - loss: 44.5246 - val_loss: 23.8723
# Epoch 100/100
# 5/5 [==============================] - 0s 11ms/step - loss: 44.9066 - val_loss: 23.8454

# %%
plt.style.use('ggplot')
plt.plot(hist.history['loss'], label='Train loss')
plt.plot(hist.history['val_loss'], label='Test loss')
plt.title('Jordan Mean Absolute Percentage Error')
plt.xlabel('Epochs')
plt.ylabel('Percentage Error')
plt.legend()
plt.savefig('imgs/jordanloss.jpeg');

# %%
jordan_preds = model.predict(test)

# %%
def plot_predictions(test,predicted):
    plt.plot(test, label='True Values')
    plt.plot(predicted, label='Predicted Values')
    plt.title('Jordan Forecast')
    plt.xlabel('Time')
    plt.ylabel('Weekly Count of Events')
    plt.legend()
    plt.savefig('imgs/jordanforcast.jpeg')

# %%
plot_predictions(y_test.values, jordan_preds)
