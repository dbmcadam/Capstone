# %% [markdown]
# ### Forecasting - Saudi Arabia

# %%
import pandas as pd 
import numpy as np 

import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, Flatten
from keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras import regularizers


pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('data/conflict-clusters.csv')

# %%
# Locating events within Saudi Arabia
data = df.loc[df['country'] == 'Saudi Arabia', :]

# %%
data.shape
# Out:
# (2881, 58)

# %%
# Dropping Columns not used in model
data.drop(columns=['year', 
                   'sub_event_type',
                   'actor1',
                   'assoc_actor_1',
                   'inter1',
                   'actor2',
                   'assoc_actor_2',
                   'inter2',
                   'interaction',
                   'region',
                   'admin2',
                   'admin3',
                   'location',
                   'timestamp',
                   'country',
                   'MA/CU'], inplace=True)

# %%
# Creating weekly event count 
df = (pd.to_datetime(data['event_date']).dt.floor('d').value_counts().rename_axis('date').reset_index(name='count'))

# %%
data['event_date'] = pd.to_datetime(data['event_date'])

# %%
# Merging event data and weekly counts
data = pd.merge(data, df, left_on='event_date', right_on='date', how='outer')

# %%
data.set_index('event_date', inplace=True)

# %%
data.drop(columns='date', inplace=True)

# %%
pd.get_dummies(data=data, 
               columns=['event_type',
                        'admin1'])
# Out:
#                                       -0.55
# 2019-12-31                                              -0.55
#
#             Corruption Perceptions Index 100 = no corruption  \
# event_date
# 2017-01-01                                                49
# 2017-01-01                                                49
# 2017-01-03                                                49
# 2017-01-03                                                49
# 2017-01-03                                                49
# ...                                                      ...
# 2019-12-23                                                53
# 2019-12-24                                                53
# 2019-12-25                                                53
# 2019-12-27                                                53
# 2019-12-31                                                53
#
#             Political rights index 7 (weak) - 1 (strong)  \
# event_date
# 2017-01-01                                             7
# 2017-01-01                                             7
# 2017-01-03                                             7
# 2017-01-03                                             7
# 2017-01-03                                             7
# ...                                                  ...
# 2019-12-23                                             7
# 2019-12-24                                             7
# 2019-12-25                                             7
# 2019-12-27                                             7
# 2019-12-31                                             7
#
#             Civil liberties index 7 (weak) - 1 (strong)   \
# event_date
# 2017-01-01                                             7
# 2017-01-01                                             7
# 2017-01-03                                             7
# 2017-01-03                                             7
# 2017-01-03                                             7
# ...                                                  ...
# 2019-12-23                                             7
# 2019-12-24                                             7
# 2019-12-25                                             7
# 2019-12-27                                             7
# 2019-12-31                                             7
#
#             Short-term political risk (1=low 7=high)  \
# event_date
# 2017-01-01                                         2
# 2017-01-01                                         2
# 2017-01-03                                         2
# 2017-01-03                                         2
# 2017-01-03                                         2
# ...                                              ...
# 2019-12-23                                         2
# 2019-12-24                                         2
# 2019-12-25                                         2
# 2019-12-27                                         2
# 2019-12-31                                         2
#
#             Medium/long-term political risk (1=low 7=high)  \
# event_date
# 2017-01-01                                               3
# 2017-01-01                                               3
# 2017-01-03                                               3
# 2017-01-03                                               3
# 2017-01-03                                               3
# ...                                                    ...
# 2019-12-23                                               3
# 2019-12-24                                               3
# 2019-12-25                                               3
# 2019-12-27                                               3
# 2019-12-31                                               3
#
#             Political violence risk (1=low 7=high)  \
# event_date
# 2017-01-01                                       4
# 2017-01-01                                       4
# 2017-01-03                                       4
# 2017-01-03                                       4
# 2017-01-03                                       4
# ...                                            ...
# 2019-12-23                                       4
# 2019-12-24                                       4
# 2019-12-25                                       4
# 2019-12-27                                       4
# 2019-12-31                                       4
#
#             Mobile phone subscribers per 100 people  \
# event_date
# 2017-01-01                                   121.48
# 2017-01-01                                   121.48
# 2017-01-03                                   121.48
# 2017-01-03                                   121.48
# 2017-01-03                                   121.48
# ...                                             ...
# 2019-12-23                                   122.03
# 2019-12-24                                   122.03
# 2019-12-25                                   122.03
# 2019-12-27                                   122.03
# 2019-12-31                                   122.03
#
#             Property rights index (0-100)  \
# event_date
# 2017-01-01                             62
# 2017-01-01                             62
# 2017-01-03                             62
# 2017-01-03                             62
# 2017-01-03                             62
# ...                                   ...
# 2019-12-23                             55
# 2019-12-24                             55
# 2019-12-25                             55
# 2019-12-27                             55
# 2019-12-31                             55
#
#             Freedom from corruption index (0-100)  \
# event_date
# 2017-01-01                                     46
# 2017-01-01                                     46
# 2017-01-03                                     46
# 2017-01-03                                     46
# 2017-01-03                                     46
# ...                                           ...
# 2019-12-23                                     50
# 2019-12-24                                     50
# 2019-12-25                                     50
# 2019-12-27                                     50
# 2019-12-31                                     50
#
#             Business freedom index (0-100)  Labor freedom index (0-100)  \
# event_date
# 2017-01-01                              74                           69
# 2017-01-01                              74                           69
# 2017-01-03                              74                           69
# 2017-01-03                              74                           69
# 2017-01-03                              74                           69
# ...                                    ...                          ...
# 2019-12-23                              72                           63
# 2019-12-24                              72                           63
# 2019-12-25                              72                           63
# 2019-12-27                              72                           63
# 2019-12-31                              72                           63
#
#             Life expectancy in years  \
# event_date
# 2017-01-01                     74.87
# 2017-01-01                     74.87
# 2017-01-03                     74.87
# 2017-01-03                     74.87
# 2017-01-03                     74.87
# ...                              ...
# 2019-12-23                     74.94
# 2019-12-24                     74.94
# 2019-12-25                     74.94
# 2019-12-27                     74.94
# 2019-12-31                     74.94
#
#             Fragile state index 0 (low) - 120 (high)  \
# event_date
# 2017-01-01                                      71.2
# 2017-01-01                                      71.2
# 2017-01-03                                      71.2
# 2017-01-03                                      71.2
# 2017-01-03                                      71.2
# ...                                              ...
# 2019-12-23                                      70.4
# 2019-12-24                                      70.4
# 2019-12-25                                      70.4
# 2019-12-27                                      70.4
# 2019-12-31                                      70.4
#
#             Security threats index 0 (low) - 10 (high)  \
# event_date
# 2017-01-01                                         6.3
# 2017-01-01                                         6.3
# 2017-01-03                                         6.3
# 2017-01-03                                         6.3
# 2017-01-03                                         6.3
# ...                                                ...
# 2019-12-23                                         6.0
# 2019-12-24                                         6.0
# 2019-12-25                                         6.0
# 2019-12-27                                         6.0
# 2019-12-31                                         6.0
#
#             State legitimacy index 0 (high) - 10 (low)  \
# event_date
# 2017-01-01                                         8.0
# 2017-01-01                                         8.0
# 2017-01-03                                         8.0
# 2017-01-03                                         8.0
# 2017-01-03                                         8.0
# ...                                                ...
# 2019-12-23                                         8.4
# 2019-12-24                                         8.4
# 2019-12-25                                         8.4
# 2019-12-27                                         8.4
# 2019-12-31                                         8.4
#
#             Public services index 0 (high) - 10 (low)  \
# event_date
# 2017-01-01                                        3.8
# 2017-01-01                                        3.8
# 2017-01-03                                        3.8
# 2017-01-03                                        3.8
# 2017-01-03                                        3.8
# ...                                               ...
# 2019-12-23                                        3.2
# 2019-12-24                                        3.2
# 2019-12-25                                        3.2
# 2019-12-27                                        3.2
# 2019-12-31                                        3.2
#
#             Human rights and rule of law index 0 (high) - 10 (low)  \
# event_date
# 2017-01-01                                                9.1
# 2017-01-01                                                9.1
# 2017-01-03                                                9.1
# 2017-01-03                                                9.1
# 2017-01-03                                                9.1
# ...                                                       ...
# 2019-12-23                                                9.3
# 2019-12-24                                                9.3
# 2019-12-25                                                9.3
# 2019-12-27                                                9.3
# 2019-12-31                                                9.3
#
#             Refugees and displaced persons index 0 (low) - 10 (high)  \
# event_date
# 2017-01-01                                                4.7
# 2017-01-01                                                4.7
# 2017-01-03                                                4.7
# 2017-01-03                                                4.7
# 2017-01-03                                                4.7
# ...                                                       ...
# 2019-12-23                                                4.4
# 2019-12-24                                                4.4
# 2019-12-25                                                4.4
# 2019-12-27                                                4.4
# 2019-12-31                                                4.4
#
#             Labor force million people  Labor force participation rate  \
# event_date
# 2017-01-01                       13.92                           56.26
# 2017-01-01                       13.92                           56.26
# 2017-01-03                       13.92                           56.26
# 2017-01-03                       13.92                           56.26
# 2017-01-03                       13.92                           56.26
# ...                                ...                             ...
# 2019-12-23                       14.63                           56.81
# 2019-12-24                       14.63                           56.81
# 2019-12-25                       14.63                           56.81
# 2019-12-27                       14.63                           56.81
# 2019-12-31                       14.63                           56.81
#
#             Percent urban population  Population density people per square km  \
# event_date
# 2017-01-01                     83.62                                     15.0
# 2017-01-01                     83.62                                     15.0
# 2017-01-03                     83.62                                     15.0
# 2017-01-03                     83.62                                     15.0
# 2017-01-03                     83.62                                     15.0
# ...                              ...                                      ...
# 2019-12-23                     83.73                                     15.5
# 2019-12-24                     83.73                                     15.5
# 2019-12-25                     83.73                                     15.5
# 2019-12-27                     83.73                                     15.5
# 2019-12-31                     83.73                                     15.5
#
#             db_50_clusters  count  event_type_Battles  \
# event_date
# 2017-01-01               2      2                   1
# 2017-01-01               2      2                   1
# 2017-01-03               2      5                   0
# 2017-01-03               2      5                   1
# 2017-01-03               2      5                   1
# ...                    ...    ...                 ...
# 2019-12-23               2      1                   1
# 2019-12-24               2      1                   0
# 2019-12-25               2      1                   0
# 2019-12-27               2      1                   0
# 2019-12-31               2      1                   0
#
#             event_type_Explosions/Remote violence  event_type_Protests  \
# event_date
# 2017-01-01                                      0                    0
# 2017-01-01                                      0                    0
# 2017-01-03                                      1                    0
# 2017-01-03                                      0                    0
# 2017-01-03                                      0                    0
# ...                                           ...                  ...
# 2019-12-23                                      0                    0
# 2019-12-24                                      1                    0
# 2019-12-25                                      1                    0
# 2019-12-27                                      1                    0
# 2019-12-31                                      1                    0
#
#             event_type_Riots  event_type_Violence against civilians  \
# event_date
# 2017-01-01                 0                                      0
# 2017-01-01                 0                                      0
# 2017-01-03                 0                                      0
# 2017-01-03                 0                                      0
# 2017-01-03                 0                                      0
# ...                      ...                                    ...
# 2019-12-23                 0                                      0
# 2019-12-24                 0                                      0
# 2019-12-25                 0                                      0
# 2019-12-27                 0                                      0
# 2019-12-31                 0                                      0
#
#             admin1_Al Madinah  admin1_Al-Qassim  admin1_Ar Riyad  \
# event_date
# 2017-01-01                  0                 0                0
# 2017-01-01                  0                 0                0
# 2017-01-03                  0                 0                0
# 2017-01-03                  0                 0                0
# 2017-01-03                  0                 0                0
# ...                       ...               ...              ...
# 2019-12-23                  0                 0                0
# 2019-12-24                  0                 0                0
# 2019-12-25                  0                 0                0
# 2019-12-27                  0                 0                0
# 2019-12-31                  0                 0                0
#
#             admin1_Ash Sharqiyah  admin1_Asir  admin1_Jizan  admin1_Makkah  \
# event_date
# 2017-01-01                     0            0             0              0
# 2017-01-01                     0            0             1              0
# 2017-01-03                     0            0             1              0
# 2017-01-03                     0            1             0              0
# 2017-01-03                     0            0             1              0
# ...                          ...          ...           ...            ...
# 2019-12-23                     0            1             0              0
# 2019-12-24                     0            1             0              0
# 2019-12-25                     0            0             1              0
# 2019-12-27                     0            0             0              0
# 2019-12-31                     0            1             0              0
#
#             admin1_Najran
# event_date
# 2017-01-01              1
# 2017-01-01              0
# 2017-01-03              0
# 2017-01-03              0
# 2017-01-03              0
# ...                   ...
# 2019-12-23              0
# 2019-12-24              0
# 2019-12-25              0
# 2019-12-27              1
# 2019-12-31              0
#
# [2881 rows x 53 columns]

# %%
data.drop(columns=['event_type', 'admin1'], inplace=True)

# %%
y = data['count']
X = data.drop(columns=['count'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False)

# %%
minmax = MinMaxScaler()

# %%
# Normalizing Data
X_train = minmax.fit_transform(X_train)
X_test = minmax.fit_transform(X_test)

# %%
X_train.shape
# Out:
# (2160, 39)

# %%
train = TimeseriesGenerator(X_train, y_train, length=3, batch_size=64)
test = TimeseriesGenerator(X_test, y_test, length=3, batch_size=64)

# %%
batch_x, batch_y = train[0]

# %%
batch_x.shape
# Out:
# (64, 1, 39)

# %%
# The LSTM design
model = Sequential()
# First LSTM layer with Dropout 
model.add(LSTM(32, activation='relu', kernel_regularizer=regularizers.l1(1e-5),return_sequences=True, input_shape=(3, 39)))
model.add(Dropout(0.7))
# Second LSTM layer
model.add(LSTM(units=32, activation='relu', kernel_regularizer=regularizers.l1(1e-5),return_sequences=True))
model.add(Dropout(0.7))
# Third LSTM layer
model.add(LSTM(units=32, activation='relu', return_sequences=True))
model.add(Dropout(0.7))
# The output layer

model.add(Flatten())
model.add(Dense(1))

# Compiling the RNN
model.compile(optimizer='Adam', loss='mean_absolute_percentage_error')
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_31 (LSTM)               (None, 3, 32)             9216
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 3, 32)             0
# _________________________________________________________________
# lstm_32 (LSTM)               (None, 3, 32)             8320
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 3, 32)             0
# _________________________________________________________________
# lstm_33 (LSTM)               (None, 3, 32)             8320
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 3, 32)             0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 96)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 97
# =================================================================
# Total params: 25,953
# Trainable params: 25,953
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting to the training set
hist = model.fit_generator(train, validation_data=(test), epochs=15)
# Out:
# Epoch 1/15
# 34/34 [==============================] - 2s 67ms/step - loss: 95.3036 - val_loss: 67.1115
# Epoch 2/15
# 34/34 [==============================] - 0s 6ms/step - loss: 66.5680 - val_loss: 22.6587
# Epoch 3/15
# 34/34 [==============================] - 0s 7ms/step - loss: 61.8258 - val_loss: 35.8135
# Epoch 4/15
# 34/34 [==============================] - 0s 7ms/step - loss: 60.3390 - val_loss: 51.0964
# Epoch 5/15
# 34/34 [==============================] - 0s 7ms/step - loss: 58.7757 - val_loss: 75.1395
# Epoch 6/15
# 34/34 [==============================] - 0s 7ms/step - loss: 57.5910 - val_loss: 84.8598
# Epoch 7/15
# 34/34 [==============================] - 0s 7ms/step - loss: 56.4352 - val_loss: 111.1747
# Epoch 8/15
# 34/34 [==============================] - 0s 7ms/step - loss: 56.0814 - val_loss: 109.3205
# Epoch 9/15
# 34/34 [==============================] - 0s 7ms/step - loss: 54.9355 - val_loss: 114.0026
# Epoch 10/15
# 34/34 [==============================] - 0s 7ms/step - loss: 54.4809 - val_loss: 139.0843
# Epoch 11/15
# 34/34 [==============================] - 0s 7ms/step - loss: 53.5348 - val_loss: 132.3922
# Epoch 12/15
# 34/34 [==============================] - 0s 7ms/step - loss: 54.0637 - val_loss: 130.2275
# Epoch 13/15
# 34/34 [==============================] - 0s 7ms/step - loss: 53.7173 - val_loss: 140.8298
# Epoch 14/15
# 34/34 [==============================] - 0s 7ms/step - loss: 54.4653 - val_loss: 138.5809
# Epoch 15/15
# 34/34 [==============================] - 0s 7ms/step - loss: 53.9070 - val_loss: 139.3803

# %%
plt.style.use('ggplot')
plt.plot(hist.history['loss'], label='Train loss')
plt.plot(hist.history['val_loss'], label='Test loss')
plt.title('Saudi Arabia Mean Absolute Percentage Error')
plt.xlabel('Epochs')
plt.ylabel('Percentage Error')
plt.savefig('imgs/saloss.jpeg');

# %%
saudi_preds = model.predict(test)

# %%
plt.style.use('ggplot')

# %%
def plot_predictions(test,predicted):
    plt.plot(test, label='True Values')
    plt.plot(predicted, label='Predicted Values')
    plt.title('Saudi Arabia Forecast')
    plt.xlabel('Time')
    plt.ylabel('Weekly Count of Events')
    plt.legend()
    plt.savefig('imgs/saforecast.jpeg');

# %%
plot_predictions(y_test.values, saudi_preds)
